# %% [markdown]
# # Random prize draw for participants of UG league study to win 1 of 30 £10 RP cards

# %%
all_participants = ['umayr_patel@hotmail.co.uk',
'cheesusg@gmail.com',
'Lucas.vetter.lv@gmail.com',
'vy.petersson@gmail.com',
'martiquerol@gmail.com',
'timhofmann52@gmail.com',
'andrewtel4@gmail.com',
'miguel.clement@telenet.be',
'ibrahimzaman814@gmail.com',
'conni.ella.tinmouth@gmail.com',
'andrewtel4@gmail.com',
'gasparyanartur99@gmail.com',
'omet2121@gmail.com',
'elmo.paka@gmail.com',
'adrianmogollon@outlook.com',
'Crixalizf@gmail.com',
'andrewtel4@gmail.com',
'samdylan200@hotmail.co.uk',
'evilbill1345@gmail.com',
'franciscomw.hk@gmail.com',
'Alex_22_pt@hotmail.co.uk',
'aj7g20@soton.ac.uk',
'Pmj516@york.ac.uk',
'ggoc500@york.ac.uk',
'saniity9@gmail.com',
'jalirio1997@gmail.com',
'domenik.brader@web.de',
'willatherton@web.de',
'kazzkarim@gmail.com',
'djwignall@gmail.com',
'alexwoodfine@gmail.com',
'aemitchell1997@gmail.com',
'emmie.langdale@gmail.com',
'robin.soosalu@gmail.com',
'chedisbad@gmail.com',
'iamlongchamp@gmail.com',
'marjolein.dirven@gmail.com',
'pkfrbydgoszcz@gmail.com',
'Bradley-whitmore@hotmail.co.uk',
'jacktingley15@gmail.com',
'parhaamb4@gmail.com',
'k.nguyen@student.reading.ac.uk',
'keenuch02@gmail.com',
'Clashnl87@gmail.com',
'Dave_13_08@hotmail.it',
'Simonas.Dambrauskas@warwick.ac.uk',
'memo1221997@gmail.com',
'emeric.n69@gmail.com',
'throwpeteaway@gmail.com',
'keenuch02@gmail.com',
'jackdredge99@gmail.com',
'malikcakir1234@gmail.com',
'mtthwjenkins@gmail.com',
'he1nm4rk@gmail.com',
'davidgillespie009@gmail.com',
'djnabster@hotmail.co.uk',
'diefenbaker.bell@gmail.com',
'vu.liem97@gmail.com',
'walid.noorestani@gmail.com',
'andreas012@live.co.uk',
'hendrik.craciun@live.de',
'ethenhaylock120@gmail.com',
'janweissbarth98@gmail.com',
'scott_lrnz@yahoo.com',
'johan.hif@gmail.com',
'girgzdas.h@gmail.com',
'bph513@york.ac.uk',
'davidpopovici01@gmail.com',
'kitlost95@gmail.com',
'malcolm.roux@colostate.edu',
'xkaritsux@gmail.com',
'lilsnubb@gmail.com Jinhang7134@gmail.com',
'randomlyme43@gmail.com',
'Nizzy2k11@gmail.com',
'dumontommy@gmail.com',
'cujoallison@gmail.com',
'ebach615@gmail.com',
'alex.gornish@gmail.com',
'franciscodias94@gmail.com',
'ebach615@gmail.com',
'ccblue93@gmail.com',
'zthorne@dal.ca',
'fbergano06@hotmail.com',
'Harpsdeathsong@gmail.com',
'obd1123@gmail.com',
'kikinak@rocketmail.com',
'commend518@gmail.com',
'William.h.love@gmail.com',
'S.sevrc1207@gmail.com',
'fireguyor@yahoo.com',
'tommyard2001@gmail.com',
'isaacvalentin160@gmail.com',
'Y.Frontzkowski@gmail.com',
'BXN092@student.bham.ac.uk',
'andrewtel4@gmail.com',
'M7emmad14@gmail.com',
'ndr.pdro@gmail.com',
'Arron.p.cook@gmail.com',
'ksbonthrone@gmail.com',
'chedisbad@gmail.com',
'sross443@googlemail.com',
'Royvanbeem@gmail.com',
'emeric.n69@gmail.com',
'Thrin_d@live.nl',
'throwpeteaway@gmail.com',
'timhofmann52@gmail.com',
'Akmd2000@hotmail.com',
'nikovigo@gmail.com',
'raphagomes.8@hotmail.com',
'adrianpitt23@gmail.com',
'Dylanbyrne189@gmail.com',
'aukjevanmontfort@hotmail.com',
'aj7g20@soton.ac.uk',
'maritdevries1@live.nl',
'ferrumimmortalis@gmail.com',
'iamlongchamp@gmail.com',
'emeric.n69@gmail.com',
'ashleykendon@hotmail.co.uk',
'smoothtt@gmail.com',
'edwards.alexander97@outlook.com',
'Krystalmyers1@hotmail.com',
'parhaamb4@gmail.com',
'raphagomes.8@hotmail.com',
'berthebaud.caleb@gmail.com',
'dhayek92@gmail.com',
'jakob.anuth@gmail.com',
'deidaraitachitobi@gmail.com',
'adrianpitt23@gmail.com',
'yordan_yankov_y@abv.bg',
'abdullahabid96@gmail.com',
'toxichris2@gmail.com',
'joeheld77@gmail.com',
'yichaoyang1357@gmail.com',
'henrywrausch@gmail.com',
'Joel.mowatt@gmail.com',
'lvsuperspree@gmail.com',
'henrywrausch@gmail.com',
'dimitri.a.smith@pepperdine.edu',
'siriusk0508@gmail.com',
'xkaritsux@gmail.com',
'victorjmarton.vjm@gmail.com',
'yichaoyang1357@gmail.com',
'abdullahabid96@gmail.com',
'William.h.love@gmail.com',
'attritionalsupernova@gmail.com',
'yichaoyang1357@gmail.com',
'Drazida@gmail.com',
'henrywrausch@gmail.com',
'ebach615@gmail.com',
'kaitookanotake@gmail.com',
'Baileysnod@gmail.com',
'bjbuckle@ucsc.edu',
'Jinhang7134@gmail.com',
'xkaritsux@gmail.com',
'Raydee93@googlemail.com',
'maltejedstrom@gmail.com',
'Linrond@web.de',
'chedisbad@gmail.com',
'deidaraitachitobi@gmail.com',
'yordan_yankov_y@abv.bg',
'davidgillespie009@gmail.com',
'yordan_yankov_y@abv.bg',
'deidaraitachitobi@gmail.com',
'marcello.piva@protonmail.com',
'ferrumimmortalis@gmail.com',
'aj7g20@soton.ac.uk',
'martiquerol@gmail.com',
'julianschopp@hotmail.ch',
'evilbill1345@gmail.com',
'jacktingley15@gmail.com',
'Dylanbyrne189@gmail.com',
'Drazida@gmail.com',
'xkaritsux@gmail.com']

len(all_participants)
# Out:
# 173

# %%
import collections

occurences = collections.Counter(all_participants)

occurences
# Out:
# Counter({'umayr_patel@hotmail.co.uk': 1,
#          'cheesusg@gmail.com': 1,
#          'Lucas.vetter.lv@gmail.com': 1,
#          'vy.petersson@gmail.com': 1,
#          'martiquerol@gmail.com': 2,
#          'timhofmann52@gmail.com': 2,
#          'andrewtel4@gmail.com': 4,
#          'miguel.clement@telenet.be': 1,
#          'ibrahimzaman814@gmail.com': 1,
#          'conni.ella.tinmouth@gmail.com': 1,
#          'gasparyanartur99@gmail.com': 1,
#          'omet2121@gmail.com': 1,
#          'elmo.paka@gmail.com': 1,
#          'adrianmogollon@outlook.com': 1,
#          'Crixalizf@gmail.com': 1,
#          'samdylan200@hotmail.co.uk': 1,
#          'evilbill1345@gmail.com': 2,
#          'franciscomw.hk@gmail.com': 1,
#          'Alex_22_pt@hotmail.co.uk': 1,
#          'aj7g20@soton.ac.uk': 3,
#          'Pmj516@york.ac.uk': 1,
#          'ggoc500@york.ac.uk': 1,
#          'saniity9@gmail.com': 1,
#          'jalirio1997@gmail.com': 1,
#          'domenik.brader@web.de': 1,
# ...

# %%
recurring_players = ['xkaritsux@gmail.com', 'andrewtel4@gmail.com', 'aj7g20@soton.ac.uk', 'chedisbad@gmail.com', 'emeric.n69@gmail.com',
                     'ebach615@gmail.com', 'deidaraitachitobi@gmail.com', 'yordan_yankov_y@abv.bg', 'yichaoyang1357@gmail.com', 'henrywrausch@gmail.com']
len(recurring_players)
# Out:
# 10

# %%
extract_unique_participants = list(set(all_participants))
len(extract_unique_participants)
print('total valid players:', len(extract_unique_participants), '\n', '\n', 'total valid players emails: ', extract_unique_participants)
# Out:
# total valid players: 135
#
# ...

# %%
remaining_prize_draw_players = [email for email in extract_unique_participants if email not in recurring_players]

print('remaining players: ', len(remaining_prize_draw_players), '\n', '\n', 'remaining players emails: ', remaining_prize_draw_players)
# Out:
# remaining players:  125
#
# ...

# %%
import random 

print(random.sample(remaining_prize_draw_players, k = 20))
# Out:
# ['Crixalizf@gmail.com', 'kitlost95@gmail.com', 'vy.petersson@gmail.com', 'aukjevanmontfort@hotmail.com', 'samdylan200@hotmail.co.uk', 'ibrahimzaman814@gmail.com', 'martiquerol@gmail.com', 'andreas012@live.co.uk', 'berthebaud.caleb@gmail.com', 'malcolm.roux@colostate.edu', 'kaitookanotake@gmail.com', 'S.sevrc1207@gmail.com', 'Royvanbeem@gmail.com', 'dumontommy@gmail.com', 'ndr.pdro@gmail.com', 'nikovigo@gmail.com', 'jakob.anuth@gmail.com', 'kazzkarim@gmail.com', 'iamlongchamp@gmail.com', 'jalirio1997@gmail.com']
